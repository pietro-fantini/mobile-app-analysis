# %% [markdown]
# # Mobile App Data Preparation

# %% [markdown]
# ### Step 1
# **Import functions** and provide the **Google Cloud Platform credentials**.

# %%
# Import functions
import pandas as pd
import numpy as np
from google.cloud import storage
from google.cloud import bigquery
import pandas as pd
from io import BytesIO
import os

# %%
# Credentials to access my Google CLoud
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/pietr/Visual Studio/mobile_dataset/app-usage-414021-1197778b794d.json"

# %% [markdown]
# ### Step 2
# **Download** the **raw data** file from Google Cloud Storage and convert it to a **pandas dataframe**.

# %%
def load_csv_to_dataframe(bucket_name, blob_name, separator):
    # Create a storage client.
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)

    # Download the blob's contents and decode as a string.
    data = blob.download_as_text()

    # Use StringIO to convert the string data into a file-like object so pandas can read it.
    string_buffer = StringIO(data)

    # Read the data into a pandas DataFrame.
    df = pd.read_csv(string_buffer, delimiter = separator)

    return df

# %%
# Bucket and file name on Google Cloud
bucket_name = 'event-app-usage'
blob_name = 'app_data_raw.tsv'
separator = '\t'
df = load_csv_to_dataframe(bucket_name, blob_name, separator)

# %% [markdown]
# ### Step 3
# **Exploratory** data analysis.

# %%
# Display the first rows of the DataFrame
df.head()
# Out:
#    user_id  session_id            timestamp                     app_name  \
# 0        0           1  2018-01-16 06:01:05  Minesweeper Classic (Mines)
# 1        0           1  2018-01-16 06:01:05  Minesweeper Classic (Mines)
# 2        0           1  2018-01-16 06:01:07  Minesweeper Classic (Mines)
# 3        0           1  2018-01-16 06:01:07  Minesweeper Classic (Mines)
# 4        0           1  2018-01-16 06:01:08  Minesweeper Classic (Mines)
#
#   event_type
# 0     Opened
# 1     Closed
# 2     Opened
# 3     Closed
# 4     Opened

# %%
# Display the last rows of the DataFrame
df.tail()
# Out:
#          user_id  session_id            timestamp            app_name  \
# 3658584      291       76247  2018-04-06 14:35:15            Facebook
# 3658585      291       76247  2018-04-06 14:35:15            Facebook
# 3658586      291       76247  2018-04-06 14:35:37            Facebook
# 3658587      291       76247  2018-04-06 14:35:37            Facebook
# 3658588      291       76247  2018-04-06 14:35:52  Facebook Messenger
#
#                event_type
# 3658584            Closed
# 3658585            Opened
# 3658586            Closed
# 3658587            Opened
# 3658588  User Interaction

# %%
# Summary of data types, missing values, and data shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3658589 entries, 0 to 3658588
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     int64
#  1   session_id  int64
#  2   timestamp   object
#  3   app_name    object
#  4   event_type  object
# dtypes: int64(2), object(3)
# memory usage: 139.6+ MB

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#             user_id    session_id
# count  3.658589e+06  3.658589e+06
# mean   1.466050e+02  3.501439e+04
# std    8.504212e+01  2.215092e+04
# min    0.000000e+00  1.000000e+00
# 25%    7.100000e+01  1.540500e+04
# 50%    1.380000e+02  3.128200e+04
# 75%    2.210000e+02  5.499700e+04
# max    2.910000e+02  7.624700e+04

# %%
app_name_df = pd.DataFrame(df['app_name'].unique(), columns= ['App'])

pd.set_option('display.max_rows', None)

app_name_df
# Out:
#                             App
# 0   Minesweeper Classic (Mines)
# 1                         Gmail
# 2                        Google
# 3                     Instagram
# 4                 Google Chrome
# 5                         Clock
# 6                          Maps
# 7                       YouTube
# 8                      Facebook
# 9                      Messages
# 10                        Phone
# 11                     Snapchat
# 12                     Settings
# 13                Google Photos
# 14                     Hangouts
# 15              Amazon Shopping
# 16           Facebook Messenger
# 17            Google Play Store
# 18                     Calendar
# 19                      Discord
# 20                 Google Drive
# 21                      Twitter
# 22                Spotify Music
# 23                       Reddit
# 24           Android In Call UI
# 25                  Receipt Hog
# 26                       Ibotta
# 27           PayPal Mobile Cash
# 28                     Contacts
# 29                Samsung Notes
# 30                    Messaging
# 31              Samsung Gallery
# 32                         eBay
# 33           Flipboard Briefing
# 34                       Camera
# 35                   Yahoo Mail
# 36                       S’more
# 37                   Lucktastic
# 38                    Pinterest
# 39         Words With Friends 2
# 40            Google Play Music
# 41                   Calculator
# 42     Samsung Internet Browser
# 43                         Hulu
# 44                      Walmart
# 45              MUIQ Survey App
# 46           WhatsApp Messenger
# 47                    Robinhood
# 48              Calorie Counter
# 49                Pandora Music
# 50            Microsoft Outlook
# 51                Samsung Email
# 52                      Netflix
# 53               Messenger Lite
# 54                 Reward Stash
# 55                      OfferUp
# 56                Brave Browser
# 57                     Slidejoy
# 58             Verizon Messages
# 59                  Samsung Pay
# 60                      TextNow
# 61                          imo
# 62                    Swagbucks
# 63                     Telegram
# 64                 Clean Master
# 65               Podcast Addict
# 66                  The PCH App
# 67                        Quora
# 68               Movie Play Box
# 69        Microsoft Bing Search
# 70                    SurveyCow
# 71                Baseball Boy!
# 72         Swagbucks Watch (TV)
# 73                  MAX Cleaner
# 74                          Kik
# 75              Army Men Strike
# 76                    MetroZone
# 77                          AOL
# 78                        Badoo
# 79                     Text One
# 80                   Telegram X
# 81                       WeChat
# 82                        Pixlr
# 83                        Faceu
# 84                       Flickr
# 85                  EntertaiNow
# 86      DigiHUD Pro Speedometer

# %%
event_type_df = pd.DataFrame(df['event_type'].unique(), columns = ['Event Type'])

event_type_df
# Out:
#          Event Type
# 0            Opened
# 1            Closed
# 2  User Interaction
# 3            Broken

# %% [markdown]
# ### Insights
# 1. The dataset has a size of 140MB and has 3.66M rows and has 5 columns.
# 2. The columns are:
#     1. **User ID**. 292 unique users were recorded, each one had at least one session (261 sessions per user on average).
#     2. **Session ID**. 72647 sessions were recorded, everyone accounting for multiple events (50 events per session on average).
#     3. **timestamp**. Timestamp column stating the time at which a certain event was carried out.
#     4. **App Name**. 86 different apps were recorded.
#     5. **Event Type**. Event occured at that given time by that user in that session with that app. There are 4 of them (Opened, Closed, User Interaction and Broken).

# %% [markdown]
# ### Step 4
# Calculate new metrics:
# 1. **Event duration**. Calculate difference between consecutive events.
# 2. **Next event**. Highlight next event for future calculations and insights on user behaviour.
# 3. **Last event**. Highlight if an event is the last of the session or of the user.
# 4. **Part of day**. Calculate which part the day the timestamp refers to.

# %%
# Assuming df is your DataFrame after loading the dataset
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Calculate time difference between current and next event
df['next_timestamp'] = df.groupby('user_id')['timestamp'].shift(-1)
df['event_duration'] = (df['next_timestamp'] - df['timestamp']).dt.total_seconds()
df.drop(columns="next_timestamp", inplace=True)

# Create a column with the next event
df['next_event'] = df.groupby('user_id')['event_type'].shift(-1)

# Reset to default pandas display option
pd.reset_option('display.max_rows')

# %%
# Create two default columns "N"
df["is_session_last_event"] = "N"
df["is_user_last_event"] = "N"

# Create two masks to identify if it is user or session last event
mask_session = df["session_id"] != df["session_id"].shift(-1)
mask_user = df["user_id"] != df["user_id"].shift(-1)

# Write "Y" in the default "N" columns with the masks
df.loc[mask_session, "is_session_last_event"]  = "Y"
df.loc[mask_user, "is_user_last_event"]  = "Y"

# %%
# Add column to identify which part of the day the timestamp refers to
def get_part_of_day(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'

df['part_of_day'] = df['timestamp'].dt.hour.apply(get_part_of_day)

df
# Out:
#          user_id  session_id           timestamp                     app_name  \
# 0              0           1 2018-01-16 06:01:05  Minesweeper Classic (Mines)
# 1              0           1 2018-01-16 06:01:05  Minesweeper Classic (Mines)
# 2              0           1 2018-01-16 06:01:07  Minesweeper Classic (Mines)
# 3              0           1 2018-01-16 06:01:07  Minesweeper Classic (Mines)
# 4              0           1 2018-01-16 06:01:08  Minesweeper Classic (Mines)
# ...          ...         ...                 ...                          ...
# 3658584      291       76247 2018-04-06 14:35:15                     Facebook
# 3658585      291       76247 2018-04-06 14:35:15                     Facebook
# 3658586      291       76247 2018-04-06 14:35:37                     Facebook
# 3658587      291       76247 2018-04-06 14:35:37                     Facebook
# 3658588      291       76247 2018-04-06 14:35:52           Facebook Messenger
#
#                event_type  event_duration        next_event  \
# 0                  Opened             0.0            Closed
# 1                  Closed             2.0            Opened
# 2                  Opened             0.0            Closed
# 3                  Closed             1.0            Opened
# 4                  Opened             0.0            Closed
# ...                   ...             ...               ...
# 3658584            Closed             0.0            Opened
# 3658585            Opened            22.0            Closed
# 3658586            Closed             0.0            Opened
# 3658587            Opened            15.0  User Interaction
# 3658588  User Interaction             NaN               NaN
#
#         is_session_last_event is_user_last_event part_of_day
# 0                           N                  N     Morning
# 1                           N                  N     Morning
# 2                           N                  N     Morning
# 3                           N                  N     Morning
# 4                           N                  N     Morning
# ...                       ...                ...         ...
# 3658584                     N                  N   Afternoon
# 3658585                     N                  N   Afternoon
# 3658586                     N                  N   Afternoon
# 3658587                     N                  N   Afternoon
# 3658588                     Y                  Y   Afternoon
#
# [3658589 rows x 10 columns]

# %% [markdown]
# ### Step 5
# In order to allow conversion analysis, a new column "is_converted" was added to identify if actually from a "user_interaction" event stemmed a conversion event (e.g., buying a product, subscribing to a service...).

# %%
# Create a new column "is converted" to simulate if the user interaction is converted
target_event_type = 'User Interaction'  # The event_type to check
probability = 0.2  # Probability of getting "Y" for the target_event_type

# Apply a function to create a new column based on conditions
df['is_converted'] = df['event_type'].apply(lambda x: np.random.choice(['Y', 'N'], p=[probability, 1-probability]) if x == target_event_type else 'N')

df
# Out:
#          user_id  session_id           timestamp                     app_name  \
# 0              0           1 2018-01-16 06:01:05  Minesweeper Classic (Mines)
# 1              0           1 2018-01-16 06:01:05  Minesweeper Classic (Mines)
# 2              0           1 2018-01-16 06:01:07  Minesweeper Classic (Mines)
# 3              0           1 2018-01-16 06:01:07  Minesweeper Classic (Mines)
# 4              0           1 2018-01-16 06:01:08  Minesweeper Classic (Mines)
# ...          ...         ...                 ...                          ...
# 3658583      291       76247 2018-04-06 14:34:34                     Facebook
# 3658584      291       76247 2018-04-06 14:35:15                     Facebook
# 3658585      291       76247 2018-04-06 14:35:15                     Facebook
# 3658586      291       76247 2018-04-06 14:35:37                     Facebook
# 3658587      291       76247 2018-04-06 14:35:37                     Facebook
#
#         event_type  event_duration        next_event is_session_last_event  \
# 0           Opened             0.0            Closed                     N
# 1           Closed             2.0            Opened                     N
# 2           Opened             0.0            Closed                     N
# 3           Closed             1.0            Opened                     N
# 4           Opened             0.0            Closed                     N
# ...            ...             ...               ...                   ...
# 3658583     Opened            41.0            Closed                     N
# 3658584     Closed             0.0            Opened                     N
# 3658585     Opened            22.0            Closed                     N
# 3658586     Closed             0.0            Opened                     N
# 3658587     Opened            15.0  User Interaction                     N
#
#         is_user_last_event part_of_day is_converted
# 0                        N     Morning            N
# 1                        N     Morning            N
# 2                        N     Morning            N
# 3                        N     Morning            N
# 4                        N     Morning            N
# ...                    ...         ...          ...
# 3658583                  N   Afternoon            N
# 3658584                  N   Afternoon            N
# 3658585                  N   Afternoon            N
# 3658586                  N   Afternoon            N
# 3658587                  N   Afternoon            N
#
# [3658588 rows x 11 columns]

# %% [markdown]
# ### Step 6
# Upload the new prepared file to **Google Cloud Storage**.

# %%
def dataframe_to_gcs(bucket_name, df, destination_blob_name):
    # Create a GCS client
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)
    
    # Convert the DataFrame to a CSV in memory.
    csv_buffer = StringIO()
    df.to_csv(csv_buffer, index=False)

    # Move to the beginning of the StringIO object.
    csv_buffer.seek(0)
    
    # Upload the in-memory CSV to GCS
    blob.upload_from_string(csv_buffer.getvalue(), content_type='text/csv')
    
    print(f"DataFrame uploaded to {destination_blob_name} in bucket {bucket_name}")

# %%
# Set your GCS bucket name and the GCS object name (path) where you want to upload the CSV.
bucket_name = 'event-app-usage'
destination_blob_name = 'app_data_prepared.csv'

# Perform the upload
dataframe_to_gcs(bucket_name, df, destination_blob_name)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: The operation did not complete (write) (_ssl.c:2406)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='storage.googleapis.com', port=443): Max retries exceeded with url: /upload/storage/v1/b/event-app-usage/o?uploadType=resumable&upload_id=ABPtcPpAVGN7VVqL4n2SZ9jDpFAACX9g8sHo1NRHUX10VEyDmhD8DU8CBkMoxTuopc-AXqpI0C0jl0a881MXpIj4NOFf0rYDbojBVg1Cx7vfBais (Caused by SSLError(SSLWantWriteError(3, 'The operation did not complete (write) (_ssl.c:2406)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[142], line 6
#       3 destination_blob_name = 'app_data_prepared.csv'
#       5 # Perform the upload
# ----> 6 dataframe_to_gcs(bucket_name, df, destination_blob_name)
#
# Cell In[114], line 15, in dataframe_to_gcs(bucket_name, df, destination_blob_name)
#      12 csv_buffer.seek(0)
#      14 # Upload the in-memory CSV to GCS
# ---> 15 blob.upload_from_string(csv_buffer.getvalue(), content_type='text/csv')
#      17 print(f"DataFrame uploaded to {destination_blob_name} in bucket {bucket_name}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\storage\blob.py:3059, in Blob.upload_from_string(self, data, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    3057 data = _to_bytes(data, encoding="utf-8")
#    3058 string_buffer = BytesIO(data)
# -> 3059 self.upload_from_file(
#    3060     file_obj=string_buffer,
#    3061     size=len(data),
#    3062     content_type=content_type,
#    3063     num_retries=num_retries,
#    3064     client=client,
#    3065     predefined_acl=predefined_acl,
#    3066     if_generation_match=if_generation_match,
#    3067     if_generation_not_match=if_generation_not_match,
#    3068     if_metageneration_match=if_metageneration_match,
#    3069     if_metageneration_not_match=if_metageneration_not_match,
#    3070     timeout=timeout,
#    3071     checksum=checksum,
#    3072     retry=retry,
#    3073 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\storage\blob.py:2766, in Blob.upload_from_file(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2627 def upload_from_file(
#    2628     self,
#    2629     file_obj,
#    (...)
#    2642     retry=DEFAULT_RETRY_IF_GENERATION_SPECIFIED,
#    2643 ):
#    2644     """Upload the contents of this blob from a file-like object.
#    2645
#    2646     The content type of the upload will be determined in order
#    (...)
#    2764              if the upload response returns an error status.
#    2765     """
# -> 2766     self._prep_and_do_upload(
#    2767         file_obj,
#    2768         rewind=rewind,
#    2769         size=size,
#    2770         content_type=content_type,
#    2771         num_retries=num_retries,
#    2772         client=client,
#    2773         predefined_acl=predefined_acl,
#    2774         if_generation_match=if_generation_match,
#    2775         if_generation_not_match=if_generation_not_match,
#    2776         if_metageneration_match=if_metageneration_match,
#    2777         if_metageneration_not_match=if_metageneration_not_match,
#    2778         timeout=timeout,
#    2779         checksum=checksum,
#    2780         retry=retry,
#    2781     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\storage\blob.py:2607, in Blob._prep_and_do_upload(self, file_obj, rewind, size, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2604 predefined_acl = ACL.validate_predefined(predefined_acl)
#    2606 try:
# -> 2607     created_json = self._do_upload(
#    2608         client,
#    2609         file_obj,
#    2610         content_type,
#    2611         size,
#    2612         num_retries,
#    2613         predefined_acl,
#    2614         if_generation_match,
#    2615         if_generation_not_match,
#    2616         if_metageneration_match,
#    2617         if_metageneration_not_match,
#    2618         timeout=timeout,
#    2619         checksum=checksum,
#    2620         retry=retry,
#    2621         command=command,
#    2622     )
#    2623     self._set_properties(created_json)
#    2624 except resumable_media.InvalidResponse as exc:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\storage\blob.py:2430, in Blob._do_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2413     response = self._do_multipart_upload(
#    2414         client,
#    2415         stream,
#    (...)
#    2427         command=command,
#    2428     )
#    2429 else:
# -> 2430     response = self._do_resumable_upload(
#    2431         client,
#    2432         stream,
#    2433         content_type,
#    2434         size,
#    2435         num_retries,
#    2436         predefined_acl,
#    2437         if_generation_match,
#    2438         if_generation_not_match,
#    2439         if_metageneration_match,
#    2440         if_metageneration_not_match,
#    2441         timeout=timeout,
#    2442         checksum=checksum,
#    2443         retry=retry,
#    2444         command=command,
#    2445     )
#    2447 return response.json()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\storage\blob.py:2266, in Blob._do_resumable_upload(self, client, stream, content_type, size, num_retries, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry, command)
#    2264 while not upload.finished:
#    2265     try:
# -> 2266         response = upload.transmit_next_chunk(transport, timeout=timeout)
#    2267     except resumable_media.DataCorruption:
#    2268         # Attempt to delete the corrupted object.
#    2269         self.delete()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\resumable_media\requests\upload.py:515, in ResumableUpload.transmit_next_chunk(self, transport, timeout)
#     511     self._process_resumable_response(result, len(payload))
#     513     return result
# --> 515 return _request_helpers.wait_and_retry(
#     516     retriable_request, self._get_status_code, self._retry_strategy
#     517 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\resumable_media\requests\_request_helpers.py:178, in wait_and_retry(func, get_status_code, retry_strategy)
#     175 # Check if (another) retry is allowed. If retries are exhausted and
#     176 # no acceptable response was received, raise the retriable error.
#     177 if not retry_strategy.retry_allowed(total_sleep, num_retries):
# --> 178     raise error
#     180 time.sleep(wait_time)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\resumable_media\requests\_request_helpers.py:155, in wait_and_retry(func, get_status_code, retry_strategy)
#     153 error = None
#     154 try:
# --> 155     response = func()
#     156 except _CONNECTION_ERROR_CLASSES as e:
#     157     error = e  # Fall through to retry, if there are retries left.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\resumable_media\requests\upload.py:507, in ResumableUpload.transmit_next_chunk.<locals>.retriable_request()
#     506 def retriable_request():
# --> 507     result = transport.request(
#     508         method, url, data=payload, headers=headers, timeout=timeout
#     509     )
#     511     self._process_resumable_response(result, len(payload))
#     513     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\auth\transport\requests.py:541, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     538 remaining_time = guard.remaining_timeout
#     540 with TimeoutGuard(remaining_time) as guard:
# --> 541     response = super(AuthorizedSession, self).request(
#     542         method,
#     543         url,
#     544         data=data,
#     545         headers=request_headers,
#     546         timeout=timeout,
#     547         **kwargs
#     548     )
#     549 remaining_time = guard.remaining_timeout
#     551 # If the response indicated that the credentials needed to be
#     552 # refreshed, then refresh the credentials and re-attempt the
#     553 # request.
#     554 # A stored token may expire between the time it is retrieved and
#     555 # the time the request is made, so we may need to try twice.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     513         raise ProxyError(e, request=request)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
# --> 517         raise SSLError(e, request=request)
#     519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='storage.googleapis.com', port=443): Max retries exceeded with url: /upload/storage/v1/b/event-app-usage/o?uploadType=resumable&upload_id=ABPtcPpAVGN7VVqL4n2SZ9jDpFAACX9g8sHo1NRHUX10VEyDmhD8DU8CBkMoxTuopc-AXqpI0C0jl0a881MXpIj4NOFf0rYDbojBVg1Cx7vfBais (Caused by SSLError(SSLWantWriteError(3, 'The operation did not complete (write) (_ssl.c:2406)')))

# %% [markdown]
# ### Step 7
# Using generative AI I created 3 side tables to have access to more data during the analysis:
# 1. **App Category**. The apps were categorized into 16 categories to allow aggregated analysis.
# 2. **User Demographic**. To every users demographic features were assigned.
# 3. **User App Feedbacks**. A rating from 1 to 5 was associated to every user-app pair.

# %%
# Display categorized app side table
bucket_name = 'event-app-usage'
blob_name = 'app_category.csv'
separator = ';'

pd.set_option('display.max_rows', None)

category_df = load_csv_to_dataframe(bucket_name, blob_name, separator)

category_df
# Out:
#                        App Name             Category
# 0                         Phone            Utilities
# 1                         Clock            Utilities
# 2                  Google Drive         Productivity
# 3                 Pandora Music        Music & Audio
# 4                          eBay             Shopping
# 5                    Yahoo Mail        Communication
# 6                      Calendar         Productivity
# 7             Google Play Music        Music & Audio
# 8                 Google Photos          Photography
# 9                       Discord               Social
# 10               Podcast Addict        Music & Audio
# 11                   Telegram X        Communication
# 12  Minesweeper Classic (Mines)                Games
# 13                Spotify Music        Music & Audio
# 14                  Receipt Hog              Finance
# 15                Samsung Notes         Productivity
# 16           Flipboard Briefing     News & Magazines
# 17                    Pinterest               Social
# 18         Words With Friends 2                Games
# 19                   Calculator            Utilities
# 20                         Hulu      Video Streaming
# 21                      Walmart             Shopping
# 22              MUIQ Survey App              Surveys
# 23            Microsoft Outlook        Communication
# 24                      Netflix      Video Streaming
# 25               Messenger Lite        Communication
# 26                Brave Browser         Web Browsers
# 27                      OfferUp             Shopping
# 28                  Samsung Pay              Finance
# 29                     Hangouts        Communication
# 30                          imo        Communication
# 31                 Clean Master            Utilities
# 32                        Quora               Social
# 33              Calorie Counter     Health & Fitness
# 34                       Ibotta              Finance
# 35                Baseball Boy!                Games
# 36                          Kik        Communication
# 37                    MetroZone                Other
# 38                      TextNow        Communication
# 39                        Badoo               Social
# 40                     Text One        Communication
# 41                       WeChat        Communication
# 42                          AOL        Communication
# 43                         Maps  Navigation & Travel
# 44                        Gmail        Communication
# 45                       Camera          Photography
# 46                       Google            Utilities
# 47                       Reddit               Social
# 48                      Twitter               Social
# 49                      YouTube      Video Streaming
# 50                     Contacts            Utilities
# 51                     Facebook               Social
# 52                     Messages        Communication
# 53                     Settings            Utilities
# 54                     Slidejoy                Other
# 55                     Snapchat               Social
# 56                     Sâ€™more                Other
# 57                     Telegram        Communication
# 58                    Instagram               Social
# 59                    Messaging        Communication
# 60                    Robinhood              Finance
# 61                    SurveyCow              Surveys
# 62                    Swagbucks              Surveys
# 63                   Lucktastic                Games
# 64                  MAX Cleaner            Utilities
# 65                  The PCH App              Finance
# 66                 Reward Stash              Finance
# 67                Google Chrome         Web Browsers
# 68                Samsung Email        Communication
# 69               Movie Play Box      Video Streaming
# 70              Amazon Shopping             Shopping
# 71              Army Men Strike                Games
# 72              Samsung Gallery          Photography
# 73             Verizon Messages        Communication
# 74            Google Play Store            Utilities
# 75           Android In Call UI            Utilities
# 76           Facebook Messenger        Communication
# 77           PayPal Mobile Cash              Finance
# 78           WhatsApp Messenger        Communication
# 79         Swagbucks Watch (TV)              Surveys
# 80        Microsoft Bing Search         Web Browsers
# 81     Samsung Internet Browser         Web Browsers
# 82                        Pixlr          Photography
# 83                       Flickr          Photography
# 84                  EntertaiNow      Video Streaming
# 85      DigiHUD Pro Speedometer            Utilities
# 86                        Faceu                Other

# %%
# Display the categories
categories_df = pd.DataFrame(category_df['Category'].unique(), columns = ['Category'])

categories_df
# Out:
#                Category
# 0             Utilities
# 1          Productivity
# 2         Music & Audio
# 3              Shopping
# 4         Communication
# 5           Photography
# 6                Social
# 7                 Games
# 8               Finance
# 9      News & Magazines
# 10      Video Streaming
# 11              Surveys
# 12         Web Browsers
# 13     Health & Fitness
# 14                Other
# 15  Navigation & Travel

# %%
# Display feedbacks side table
bucket_name = 'event-app-usage'
blob_name = 'user_demographic.csv'
separator = ';'

pd.reset_option('display.max_rows')
pd.set_option('display.max_columns', None)

demographic_df = load_csv_to_dataframe(bucket_name, blob_name, separator)

demographic_df
# Out:
#      User ID  Age  Gender    Country City Size Employment Status  \
# 0          0   43    Male      Italy     Large          Employed
# 1          1   56  Female      Japan     Large          Employed
# 2          2   46  Female    Germany     Large          Employed
# 3          3   32  Female  Australia     Large          Employed
# 4          4   60  Female      Japan     Large          Employed
# ..       ...  ...     ...        ...       ...               ...
# 288      288   42    Male  Australia    Medium           Student
# 289      289   52    Male  Australia     Small           Retired
# 290      290   42    Male         UK     Large        Unemployed
# 291      291   46   Other        USA     Large           Student
# 292      292   35    Male        USA     Large           Retired
#
#     Education Level Annual Income (USD) Marital Status   Interests  \
# 0        Bachelor's       20,000-40,000        Married  Technology
# 1          Master's            >100,000        Widowed  Technology
# 2               PhD      80,001-100,000        Married      Travel
# 3               PhD       20,000-40,000       Divorced       Music
# 4               NaN       40,001-60,000       Divorced  Technology
# ..              ...                 ...            ...         ...
# 288             NaN       20,000-40,000         Single       Music
# 289             NaN       60,001-80,000        Married      Gaming
# 290     High School       20,000-40,000        Widowed      Gaming
# 291     High School       60,001-80,000       Divorced      Sports
# 292             PhD            >100,000        Widowed     Cooking
#
#      Number of Dependents Home Ownership Vehicle Ownership Employment Sector  \
# 0                       2            Own               Own           Private
# 1                       1           Rent               NaN           Private
# 2                       1           Rent               NaN        Unemployed
# 3                       2           Rent               Own           Private
# 4                       4            Own               NaN           Private
# ..                    ...            ...               ...               ...
# 288                     2          Other               NaN           Private
# 289                     2           Rent               Own            Public
# 290                     2          Other               NaN            Public
# 291                     2            Own               Own            Public
# 292                     1           Rent               Own           Private
#
#                  Hobbies Dietary Preferences Favorite Movie Genre  \
# 0     Outdoor activities               Vegan               Horror
# 1     Outdoor activities               Vegan              Fantasy
# 2                    NaN       No preference               Comedy
# 3    Technology projects         Pescatarian               Horror
# 4                    DIY       No preference              Fantasy
# ..                   ...                 ...                  ...
# 288                  NaN          Vegetarian      Science Fiction
# 289              Fitness          Vegetarian              Romance
# 290                  DIY          Meat-eater      Science Fiction
# 291         Volunteering         Pescatarian                Drama
# 292                 Arts          Meat-eater              Romance
#
#     Travel Frequency Physical Activity Level Pet Ownership     Smoking Status  \
# 0            Monthly       Moderately active           Cat  Occasional smoker
# 1          Quarterly       Moderately active           Cat  Occasional smoker
# 2         Biannually       Moderately active           NaN         Non-smoker
# 3            Monthly       Moderately active           Dog         Non-smoker
# 4              Never       Moderately active         Other         Non-smoker
# ..               ...                     ...           ...                ...
# 288          Monthly             Very active           NaN             Smoker
# 289           Yearly               Sedentary           NaN  Occasional smoker
# 290        Quarterly       Moderately active         Other  Occasional smoker
# 291           Yearly       Moderately active           Dog             Smoker
# 292            Never               Sedentary           NaN         Non-smoker
#
#     Alcohol Consumption
# 0        Social drinker
# 1        Social drinker
# 2           Non-drinker
# 3        Social drinker
# 4        Social drinker
# ..                  ...
# 288      Social drinker
# 289     Regular drinker
# 290         Non-drinker
# 291     Regular drinker
# 292     Regular drinker
#
# [293 rows x 22 columns]

# %%
# Display feedbacks side table
bucket_name = 'event-app-usage'
blob_name = 'user_app_feedback.csv'
separator = ';'

feedback_df = load_csv_to_dataframe(bucket_name, blob_name, separator)

feedback_df
# Out:
#        user_id                      app  user_feedback
# 0            0                    Phone              4
# 1            0                    Clock              1
# 2            0             Google Drive              3
# 3            0            Pandora Music              5
# 4            0                     eBay              2
# ...        ...                      ...            ...
# 25399      291                    Pixlr              5
# 25400      291                   Flickr              1
# 25401      291              EntertaiNow              4
# 25402      291  DigiHUD Pro Speedometer              4
# 25403      291                    Faceu              3
#
# [25404 rows x 3 columns]

# %%
feedback_df.describe()
# Out:
#             user_id  user_feedback
# count  25404.000000   25404.000000
# mean     145.500000       3.002008
# std       84.294304       1.417118
# min        0.000000       1.000000
# 25%       72.750000       2.000000
# 50%      145.500000       3.000000
# 75%      218.250000       4.000000
# max      291.000000       5.000000
